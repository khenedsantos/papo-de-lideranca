# %% [markdown]
# # Papo de Lideranca no Google Colab
#
# Notebook base para gerar, visualizar e enviar a newsletter.

# %%
# !pip install jinja2

# %% [markdown]
# ## Opcional: montar Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/seu_caminho/New project

# %%
from papo_de_lideranca import export_newsletter_html, generate_newsletter_html

html = generate_newsletter_html(
    recipient_name='Leitor Colab',
    intro_message='Selecionamos reflexoes praticas para sua proxima etapa de crescimento.'
)

preview_path = export_newsletter_html(recipient_name='Leitor Colab')
print('Preview salvo em:', preview_path)

# %%
from IPython.display import HTML
HTML(html)

# %% [markdown]
# ## Envio por Gmail SMTP
#
# Use uma senha de app do Gmail.

# %%
# from papo_de_lideranca import send_newsletter_email
# send_newsletter_email(
#     sender_email='seu_email@gmail.com',
#     app_password='sua_senha_de_app',
#     recipient_email='destinatario@exemplo.com',
#     subject='Papo de Lideranca | Nova edicao',
#     html_content=html,
# )
